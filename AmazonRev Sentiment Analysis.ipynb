# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Amazon_Unlocked_Mobile.csv')
df.head()
df = df.iloc[0:50000,:]
df.shape
# Out:
# (50000, 6)

# %%
df=df[['Reviews','Rating']]
df=df.dropna()
df.head()

# %%
#Removing the neutral reviews
df=df[df['Rating']!=3]

# %%
df=df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 2 columns):
# Reviews    1850 non-null object
# Rating     1850 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 29.0+ KB

# %%
df['sentiment']=np.where(df['Rating'] > 3, 1, 0)
df.head()
# Out:
#                                              Reviews  Rating  sentiment
# 0  I feel so LUCKY to have found this used (phone...       5          1
# 1  nice phone, nice up grade from my pantach revu...       4          1
# 2                                       Very pleased       5          1
# 3  It works good but it goes slow sometimes but i...       4          1
# 4  Great phone to replace my lost phone. The only...       4          1

# %%
#importing libraries needed for NLP
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
#The preprocessing Step and creation of BagOfWords
texts=[]
for i in df.Reviews:
    text=re.sub("[^a-zA-Z]"," ",i)
    text=text.lower()
    text=nltk.word_tokenize(text)
    lemma=nltk.WordNetLemmatizer()
    text=[lemma.lemmatize(word) for word in text if not word in set(stopwords.words('english'))]
    text=" ".join(text)
    texts.append(text)
    
texts
# Out:
# ['feel lucky found used phone u used hard phone line someone upgraded sold one son liked old one finally fell apart year want upgrade thank seller really appreciate honesty said used phone recommend seller highly would',
#  'nice phone nice grade pantach revue clean set easy set never android phone fantastic say least perfect size surfing social medium great phone samsung',
#  'pleased',
#  'work good go slow sometimes good phone love',
#  'great phone replace lost phone thing volume button work still go setting adjust job eligible upgrade phone thaanks',
#  'already phone problem know stated used dang state charge wish would read comment would purchased item cracked side damaged good trying charge another way work requesting money back get money back signed unhappy customer',
#  'charging port loose got soldered needed new battery well later including cost purchase usable phone phone sold state',
#  'phone look good stay charged buy new battery still stay charged long trashed money lost never buy person',
#  'originally using samsung galaxy sprint wanted return back samsung epic g sprint really missed keyboard really liked smaller compact size phone still needed basic function smart phone e checking e mail getting direction text messaging phone powerful newer cell phone aware application install slower phone run likely freeze time time camera work great video great well even web browsing decent give need also notice battery life last little bit longer charging phone much quicker galaxy',
#  'great product came two day ordering one little blemish side care long phone fullly functional recommend product anyone reading',
#  'guy best little situation item quickly fixed issue pleased definitely buying another phon need one',
#  'really disappointed phone service phone went week ago instead handling issue first surfaced told stick phone dollar service using still received mailing label return item first purchase amazon rushing use smartphones business anytime soon thought getting deal seems like one lucked',
#  'ordered phone replacement model contract expires get new one seller confirmation said delivery could take day seller sent phone within hour receiving order phone next day phone look better described able transfer data old one new one problem highly recommend seller',
#  'phone loved working got phone one thing sd card slot open try access file managment even show computer card fine able open another phone trying trouble shoot',
#  'able get phone previously owned keyboard touch screen best phone love still clean device service provider well worth',
#  'brought phone replacement daughter hard cell phone must say great purchase phone work wonderful thank',
#  'love phone everything need work great purchased four phone seller shipped amazon warehouse problem phone come micro sd card use camera got card problem getting activated sprint',
#  'battery old used barely hold charge otherwise issue phone',
#  'pro beautiful screen capable running chrome take good picture keyboard comfy fit pocket fit hand play really good video gamescons bluetooth came late run fast really quick doesnt play p video would still recommend like talk text lot like watch lot movie',
#  'purchased phone december christmas present son called sprint activate phone find esn clear told come store upon research phone clear reached company inform esn clean told send phone back would send another phone asked representative provide esn could call make sure clear told phone available guaranteed would clear known something wrong received second phone turned clear esn representative sprint informed seller phone aware esn clear send another phone back asked refund phone shipping since sent two phone clear esn received refund phone yet see refund shipping suggest buy anything',
#  'phone good little slow phone old great phone temporary right thank great deal',
#  'phone speaker little low overall happy phone would purchase another cell phone chubbietech satisfied',
#  'phone great good condition daughter happy andriod user',
#  'phone work great problem',
#  'good condition work good',
#  'good phone great screen resolution storage low need sd card anything may clear esn expect use thing like freedompop',
#  'described fast ship',
#  'perfect every way',
#  'one phone bad charger port want send back',
#  'got phone great phone easy use',
#  'phone great gotten old time replacement great lasted',
#  'phone came great condition great price brings back great memory owning phone',
#  'met expectation complain great price',
#  'phone working planning use whatsapp anyway oh problem change idiom',
#  'excellent product perfect condition',
#  'excellent',
#  'excelente',
#  'excelente',
#  'like phone bought mom love',
#  'came arabian keyboard',
#  'love',
#  'practical user friendly phone satisfied',
#  'sharp classy phone',
#  'good',
#  'gooddd',
#  'shipped quickly exactly expected',
#  'work wonderful price',
#  'bought alternative smart phone data plan use go phone pay go plan phone function great radio music player good sound quality smart phone type feature easier faster use smart phone used software glitch documented nokia support site proved easily fixed even though many nokia based feature longer supported microsoft still use feature needed accessing web directly via wifi connection data want pay privilege launching site application although new nokia browser pretty spartan appearance fast run good stability big guy land large even size find full qwerty keyboard pretty easy use like programmable hot key screen shortcut keep launching item require data connection accident back lighting thorough even raised button tactile positive click response phone quirk airplane mode far tell flight profile seem able set broadcasting receiving function turned main navigation button mouse little small always respond expected might though would recommend phone vendor highly want feature smart phone need gps big data bill every month bunch thing need want keep life running smoothly',
#  'muy buen producto',
#  'phone trapped want simple phone get old school flip phone want something also work get blackberry somthing new even middle two another dimension nothing frustration phone',
#  'excellent',
#  'friend mentioned phone worth said thanks lot friend',
#  'used unlocked gsm nokia asha philippine recently jan feb excellent problem functionality bought p sim card airport presto worked passed brother instant came back u visiting philippine soon easy use used smart phone w touch screen surprised worked w easily read instruction operate buy another one like definitely upgraded version nokia unlocked gsm phone',
#  'excelente',
#  'excellent phone youngest son walk reasonable option quality first',
#  'excelente',
#  'solid phone',
#  'good choice',
#  'perfect practical easy handle good resolution well packed',
#  'excellent product right recommend',
#  'excelente',
#  'excelente',
#  'nokia brand used telephone good price excellent team gift daughter liked easy use affordable price recommend',
#  'first let say nokia user since first cell phone age ten year ago course one year ventured samsung land phone died back nokia went always enjoyed nokia phone second looking qwerty phone internet video mp playing capability asha fit strong build dropped numerous time phone still intact like keyboard fan touchscreen get asha far sound think depends headphone earbuds produced loudness decibel made listening experience mediocre bought bud db loudness sound much better nokia xpress bit sucky downloaded opera browser phone work slightly better internet experience pretty easy get video game sn even pc reason use phone wish built antenna could listen radio without rds earbuds really great phone want move blackberry want pay much nokia asha great phone start edit october found gino cm section telescoping stainless steel fm radio antenna mm plug use playing radio speaker really enjoying phone sitting outside friend desk',
#  'nokia asha unlocked gsm phone mp camera video qwertydependabletraditional nokia menu snot complicated like smart phone durableeasy use straighttalk internet wifi bluetooth',
#  'solidly built unlocked phone update popular nokia c run software good bad good reception nice audio g support band mobile hspa refarmed pc band band keyboard pretty good firm nokia qwerty phone e g e comparable c keyboard one obviously world market since added european char symbol keypad wi fi work fine opera mini installed run without problem good way go bit web surfing tried e mail social client text messaging set normal box conversation mode ovi store app seem work well couple feature found appealing ability backup phone memory sd card ability lock keypad passcode either manually automatically set time battery fairly good sized bl j function key pad key assigned user defined short cut opinion worthy update g c quite league expensive e multi tasking software price around unlocked feature gsm g phone well worth considering long one know one getting non smart phone apps limited',
#  'hola compramos do tel fonos vienieron totalente diferentes uno vino con la bater da ada se descarga de inmediato el otro tel fono vino sin la tarjeta de memoria los teclados cargadores son muy distintos mi yo no sentimos enga ada defraudadas',
#  'cellphone easy using complete apps important contact people incorporated use wi fi connection satisfied purchased simple phone complete important',
#  'gracias llego el procto que compre llevo en el momento indicado en un buen envalaje lo recomiendo sastifactoriamente',
#  'freeze alot bought primarily playing back music instead bb great phone sm ring really loud body strong neat',
#  'key little hard hit expect spanish keyboard overall good phone',
#  'preface would considered smartphone united state nothing par android iphone window phone basically feature phone also although say u warranty warranty material came referenced latin american country sure really covered u warranty returned amazon return window issue phone review pro phone great keyboard familiar e series phone type keyboard interface sort modified symbian liked lot way style hardware attractive gray nice color camera pretty decent considering megapixels e mail adequate con start small issue work big problem ultimately made decide return phone onboard social network apps fully functional update facebook twitter status rest ovi store general poor app store phone able use many even old facebook app used old e used called snaptu facebook since renamed facebook everyone incompatible phone better apps ovi store browser mediocre barely passable also gps phone nokia ovi map incompatible bad always nokia strength immediately eliminates phone smart phone said bought phone wife really needed phone text call could overlooked thing problem could overlook shabby flimsy piece metal supposed hold place standard sim card little piece metal barely attached phone would lock place hold sim card sim card would intermittently get lose inside phone constantly lose signal would take battery adjust sim card would work little ultimately repeat process way frustration worth bad basic phone call text e mail occasionally updating facebook twitter status phone lot potential becuase problem sim card holder however essentially unusable used nokia phone year use lumia personally really surprised nokia would sloppy job something important part hold sim card place waste',
#  'received phone day ago put consumer cellular sim card ready go phone seems nice even though come close discovering thing large number ring tone built',
#  'bought phone christmas present wanted something bit advanced nokia c purchased amazon want go way smartphone word good feature phone smartphone feature without touch screen red however favorite color went white one c silver find silver asha amazon week work great best wi fi feature give access web without purchasing data plan may want access personal email go facebook great calendar alarm clock text messaging camera missed received call feature c make keeper little bigger wider screen big fit pocket purse use nokia charger c await arrival purple phone skin right nokia phone since never let get better',
#  'phone pretty good using lycamobile plan thing awkward bottom row letter compared phone device using blackberry trying type nokia always mistyping m n espectially shift key need hit insert punctuation',
#  'loved everything also look like touch phone make stylish yet classic',
#  'solution want looking economic sophisticated price good choice product receive recommend',
#  'phone excellent phone great price impressed feature phone would recommend anyone',
#  'good phone although seems small screen however capable performing basic function calling messaging web browsing social networking also wi fi capability',
#  'long time user iphone finally got sick sold wanted simple phone going fit bill well texting interface nice intuitive battery life stellar connects internet fine check email case emergency look direction etc basically everything able smartphone without bell whistle physical keyboard quite nice o seems stable snappy thing like calendar todo memo etc backup snap insert sd card go setting back itunes want add music podcasts plug computer copy paste sd card done would buy phone definitely broke lost',
#  'phone like nokia feature phone great value durability last phone buying one nokia c also great phone lasted year probably would kept going accidentally jumped pool pocket p phone basically update c sleek small full qwerty keyboard wi fi internet browsing best phone get looking functionality want throw hundred dollar smartphone data plan buyer aware smartphone looking anything like smartphone disappointed looking toy take pocket every couple minute tinker around disappointed yes internet browser work well screen quite small good recreational browsing use look thing work fine also social network apps use know well work priority phone probably best choice go camera use speak quality camera important best choice potential negative see phone key really pretty small issue personally someone big hand see could annoying bought phone advantage owning smartphone longer battery life higher durability lower cost still good accomplishing need looking thing nokia definitely best way go',
#  'love',
#  'sorry took long reply review purchase month phone clone phone hong kong quality fair symbol match phone work think amazon boycott seller',
#  'bought gift mum love strong durable phone good reception function well',
#  'incredible phone splaniish language dont understand international version lost money',
#  'bad',
#  'good',
#  'battery died le hour',
#  'excellent product',
#  'well',
#  'connect gsm network',
#  'cell phone exceeded expectation user friendly everything work like said would price amazingly cheap feature enormous helpful',
#  'pro work fine easy use heavy con apps android iphone bb',
#  'went lot review different phone buying found phone pretty good problem far',
#  'excelente',
#  'excelente',
#  'phone work great look great shipped quiet quickly issue european charger purchase micro usb usb cable charge phone would download update system way',
#  'ver good',
#  'excellent phone special function communicated social network excellent operational recommend excellent product',
#  'buy feel like pretended toy hand want kid ok',
#  'excellent phone adult recommend whatsapp internet app radio keyboard qwerty easy use display big visualiser funny',
#  'enjoyed nokia c phone year tired needed update asha phone symbian simple goodness much higher quality set hardware screen sharper processor faster phone take nice clear picture pretty much good enough ring alert tone discreet professional internet mail stuff actually useable mobile g network requires little data stay connected minumal plan strangely wifi yet receives signal insists using network data nothing probably setting menu toggled right setting anyway want phone text easily day battery convenient useable feature yet crack open crack pipe internet constanly asha style may get another one two future bet end run type practical phone',
#  'got phone work took verizon store battery work even charged hr verizon put another used battery phone started work',
#  'liked',
#  'great arrived quickly',
#  'phone work great may get sum card adapter make micro sim cat work',
#  'avianna llc incredible seller phone take get place however phone work provider andrew stayed phone tech support service provider hr try get phone work work immediately sent replacement phone use receptive feedback constantly contact problem arises product described used sprint unlocked blackberry bold believe service provider problem',
#  'exactly expecting thank',
#  'got faster expected needed job thanks lot',
#  'exelente',
#  'phone work great price although got ups ups guy dropped screen door big door',
#  'keeping mind sub phone generally advertised cheapest quad core phone landvo l turned good phone exceeded expectation research landvo seems new company l first model released march took risk although le huge risk buying april review available main thing looking powerful inexpensive phone price point battery life also major factor purchased phone basis phone price range time quadcore processor also sport mah battery largest battery price point available model lot thing immediately liked phone despite low resolution lack ip screen pretty crisp viewing angle decent battery life also good averaging two day average use full charge one day heavy use would usually put around range still bad also almost shocked build quality phone heavier name brand competition size class weighty solid feel side metal volume rocker power button creak everything fit together tightly fit finish top notch believe screen plastic glass however pro con plastic screen susceptible scratching however mean never worry cracked screen drop phone phone came screen protector prefitted phone additional one box included silicone case relatively simple also nice touch especially owing fact name brand phone unlikely third party support case however would recommended phone anyone time performance lackluster quadcore soc quite snappy however small mb ram suffering android wary purchasing phone le gb ram regretting point would freeze stutter even simplest task hammering text put forth best effort streamline system much possible keep running smoothly fact enough ram power android comfortably ready ditch phone something new completely changed tune however hesitate recommend phone heartbeat surprisingly landvo supported releasing official kitkat rom phone tech savvy boon kitkat actually streamlined google device mb ram run comfortably bit resource hog point figured nothing lose planning dumping phone anyways needle say flashing kitkat made world difference performance literally night day upgrading literally got rid lag experiencing phone quite fast would argue faster sero pro tablet running old venerable tegra processor demanding apps load quickly without stuttering animation smooth everything become joy use phone looking ridiculously cheap fast android phone good battery life good build quality one looking hand going compete totl phone measly expecting get perfectly usable phone almost throw away price noticed vendor selling l android already installed look like new stock phone upgraded tech savvy comfortable flashing phone make sure purchase one already installed love',
#  'good product recomended need fast good looking good thank',
#  'autistic son glory lol thank',
#  'around good phone glitchy laggy fee problem storage small gb camera poor quality pretty certain buy galaxy camera install phone around pretty great phone',
#  'problem taking phone straight talk phone came week thing like camera horrible trying get take picture picture clear',
#  'delivery fast overall quality phone like price cheap good quality camera one feature use also durable screen damaged inch drop however suppose get pay month willing buy real phone lose terrible one',
#  'perfect',
#  'worked ok awhile every time tap back shuts',
#  'great phone sone happy needed get extra micro sd card storage',
#  'good excellent',
#  'first got phone poor camera one day hit phone pencil turned immediately like phone whatsoever would recommend getting phone especially like take lot picture use lot apps storage also poor',
#  'cheap fast',
#  'good cell',
#  'responsible seller excellent product',
#  'muy bueno',
#  'fino fino',
#  'exelentes equipos en lenguaje criollo son una verdaderas nave',
#  'good',
#  'great price hate change lock screen wantand default wallpaper lockscreen',
#  'got new phone loved phone android small limited would let set sd card want may upgrade new android heard work better figure using straight talk problem setting straight talk apn setting far want find better protection case found like hopefully make one phone',
#  'like fm radio feature charge cradle switched back lg flip phone cost le best buyreception weak signal area good lg phone mobile networkbacklighting uneven keypad number really bright phone user manual small phone designed older people manual size phone fit small box shipping manual explain use button clear concise way get alarm repeat daily turning alarm would cancel alarm next day',
#  'bouht phone year old mother macular degeneration love easy see big number dialing',
#  'like ad love',
#  'family member zero interest learning anything tech year ago gave old mobile pre paid flip phone kept year backup phone perfect want learn anything else problem phone button small getting hard ordered put sim away went love lot extra stuff ever decides want learn love much larger button dead simple use want',
#  'good quality phone',
#  'work well mobile mobile close tower non mobile phone',
#  'screen size good easy read sound could little louder okay setting little cryptic get job done extra key stokes really needed care way setup texting hit button twice get capital letter hit turn capital brand phone automatically capitalized first letter period one still good phone though worth money',
#  'like th cellphone dad le year dad always type heavy labour work process always end destroying process well first impression recieved cellphone mail keypad really like number huge also display quite clear crispy simple understand problem adjusting new device fm radio need headphone work camera ok best plausible sd slot medium play music video file dont show try search folder memory like led light alert notification plus ringtones pretty loud good pick aging parent',
#  'really great phone visually impaired problem getting another one partner',
#  'complicated expected terrible reception hard mom use frustrates',
#  'phone reception poor incoming call',
#  'nice phone easy read screen senior tech learning curve steep support jethro however made easy knowledgeable easy understand patient willing help would recommend phone so button good feature limited use telephone much le expensive tool life line',
#  'sleek design easy use make phone really good large text plus',
#  'husband love simple use large number simpler better',
#  'even instruction book better ever senior need big print phone website page clearly tell u senior take instruction go place especially traveling computer readily hand remember laptop generation getting tablet often small otherwise far great love name ask brother jethro leaving',
#  'phone purchased father really like feature price excellent deal took exactly month get everything working phone issue phone first unlocked phone consumer cellular manual came phone good thing manual match phone received lot help jethro jeffrey jethro godsend extremely helpful always cheerful voice called sent picture etc whatever took help issue even though obvious problem jethro end really like phone star jeffrey hope jethro realizes great employee',
#  'work good g simple use frill',
#  'simple sleek minimalist accepts sim perfect back phone nice matte finish pretty emerald green notification light cool alarm ringtones could improved limited space message stop accepting txts even adding sd card help programmed utilize message camera worse security footage even bother menu structure intuitive',
#  'sound like water shuts call',
#  'contacting jethro customer service couple key sticking speaking rep noticed breaking much told phone g likely work well area kind enough send g phone model sc one seems working fine far must say best customer service response solve issue',
#  'new edition jethro sc v flip quad band unlocked gsm senior kid cell phone so emergency button large lcd large keypad nice phone easy operate cost friendly also light easily portable use micro sim save music photo',
#  'everything great hard time getting old sim card work verizon hooked',
#  'bought phone supposedly able work straighttalk tracfone put tracfone sim card board bought buck straighttalk minute card discovered compatible straighttalk ther local wally world want least buck sim card kit work supposedly daughter worked hour called every available number good expert today high tech cheaper tracfone card available ask daughter take another try time job family take care another point way manual use download pdf print regular page otherwise reader strength magnifying glass recommend anyone particularly elderly people ready turn',
#  'met expectation easy use gave gift veto elderly relative love',
#  'bought phone year old aunt seems easy use would certainly recommend purchased another brand senior phone price last week due quality phone screen',
#  'received product',
#  'good phone elderly people',
#  'bought mom love',
#  'searched unlocked flip phone old mobil longer work house look good capability second minisim need simplicity husband barely answer flip phone let alone use desire buy mini sim believe badly described manual bad english seems different phone',
#  'unhappy purchase first paid shipped received found staight talk would longer work att cell phone carrier area able send back pay postage happy ken',
#  'computer programmer admit never made transition smartphone mainly sit computer everyday anyway need access smartphone apps use laptop besides screen tiny farsighted mean use smartphone going carry even item reading glass adventurous type biking motorcycling hang gliding scuba etc could find need assistance one risky adventure live alone might need get help car breakdown home injury situation bought one pre paid cell thought go problem solved kept pocket dialing see screen either worse thing battery would go dead every day since never used cell phone except emergency would always always forget charge prepaid work emergency phone jethro solved problem big screen clamshell inexpensive pre paid soooo much useful clamshell get pocket dialing big screen carry reading glass around actually using little taking todo note using calculator well great fm radio flashlight battery last week standby mode honestly used yet real emergency phone call yet placed several test call work great jethro took pre paid mobile sim problem running minute need cellphone throw backpack glove box case emergency plus inexpensive break lose biggie',
#  'fast shipping accurate description',
#  'phone unable maintain signal week usage tmobile network hope defected product',
#  'great phone',
#  'shortly return window closed stopped taking charge turn',
#  'stopped working month happy phone',
#  'defective product placed mobile sim card phone read recommend purchasing phone',
#  'sound quality poor speaker phone',
#  'great phone',
#  'excelente',
#  'phone met expectation dad loved enjoying',
#  'bought elderly grandfather vocal everything get whether like like phone loud simple need glass use able sync',
#  'needed older relative',
#  'gift grandma south america loved thanks',
#  'speaker garbage tell time military time',
#  'bought phone elderly parent put sim card phone jethro worked problem dropped call would receive make phone call phone would hang person line asking refund carrier phone bar phone call took place',
#  'great simple phone getting harder harder find want smartphone need phone elderly family member someone tech savvy great little phone gave four star though carrier recognize signature phone wound buy friendly phone phone work billed system would automatically charge smartphone extra bill since recognize signature giving military reuse',
#  'granny use phone able use locking phone function without lock phone called people phone pocket lock easier phone would great',
#  'good sound easily used senior end button also turn button elderly mom keep turning phone find another one would purchase purchase delivery scheduled',
#  'really surprised phone fm radio flashlight so feature nice well mom',
#  'nice big number everywhere simple',
#  'ordered phone would work called company told due lack tower found odd since cell',
#  'good hope phone senior reminiscent cordless house phone make easy use year old button light bright ringtone volume adjustable max loud enough anyone hearing problem though surprisingly call volume adjustable though louder previous verizon flip phone max volume set cricket service phone take mini sim card micro someone else stated buy another sim card micro ordered small mini sims original large card live u know people claiming phone work u paid ish phone would paid design functionality side note concerned grandmother would always accidentally hit so button phone disabled setting',
#  'good',
#  'thank',
#  'easy use mother use well',
#  'sim card provider would work phone returning phone',
#  'purchased phone parent difficulty small button phone thanks size button display squinting also love key raised menu layout also simple use programmable number make easy call frequently used number ringer volume good would buy',
#  'little bit effort able familiarize phone using became intuitive came nice easy read booklet purchasing checked see web site inserted sim card charged battery took couple hour several problem first first cell phone much experience mistakenly set language portuguese figure luckily several online tutorial web site restored phone factory setting english able figure phone easily one thing figured use military time pm equal setting time pm setting happy phone hearing impaired able hear basic ring loud put pocket face keypad leg speaker come back even louder thing set table put face ring loud clear questioned using lanyard e mailed jethro company got right back confirmed small hole upper left side could accommodate lanyard removing back feeding lanyard hole looping around replacing back customer service nice answered question easy understand manner phone lock pocket wont random dial need press asterisk screen say phone unlocked dial phone always accepts call without turning exactly simple phone looking returned several work went model use consumer cellular le expensive aarp discount get hour talk per month',
#  'great simple use phone mother big button easy see use use one arm charge cradle great benefit easy setup good clarity get good signal',
#  'bought mom late highest rated senior phone stopped working hated phone confusing operate menu function took chance one despite complaint read review problem addressed corrected longer difficult lock unlock key press lower left button couple second word locked come assume since say spanish set mom phone spanish second way directional key need try since mom got right away definitely good technology another complaint clock set military hr time well choose set hr phone easy set relief compared previous phone let face non senior probably set sometimes effort simplify phone take away button make harder navigate phone light weight ringer loud enough like cradle easier senior beat price worked well sim card negative side agree one complaint loud enough turned volume way afraid mom would able hear caller agreed give chance may exchange since hearing great back cover thin plastic afraid break removed wish alarm come senior phone slim picking one half price old one come close meeting requirement since senior hard hearing really need make louder',
#  'returning product volume absolutely abysmal even maximum audible bought elderly mother way able hear anything phone marketed elderly disgrace',
#  'simple use seem get tiem update',
#  'perfect great inexpensive phone senior bright large backlit number clear control large number button light weight flash light gsm paid almost wanted one breath fresh air smart phone good battery life really lucked choosing might buy another one backup father tends misplace thing used giv mobile unlimited talk text mb data month contract',
#  'good phone mom big number however setting somewhat confusing',
#  'lock accidentally used screen small read text message easy use elderly person',
#  'bought phone grandma make receive call tried manual selection network also factory reset nothing happened',
#  'good phone emergency number nice big easy use thank much',
#  'work iwirless',
#  'cyrillic surprize',
#  'bought phone year old mother hearing impaired could hear well',
#  'arrival phone charge frustrating',
#  'look good advertised instruction easy follow key quite large fairly easy see',
#  'dad love work great confusing bell whistle',
#  'bad week bought could turn offnot worth hassle buy',
#  'grandma love could bigger screen ringtones',
#  'looking',
#  'mom like kind change taken time effort get embrace versus old flip phone',
#  'pro cradle nice lack camera cheaper snapfoncons reception terrible mobile phone work inside house except one apparently g phased expect reception get worse time time date set automatically seriously year unlike every phone button directly screen actually navigation button speed dial probably problem someone first phone drove nut fcc id phone might illegal use u poor manufacturing quality battery hard insert remove battery slightly big part supposed fit voice mail number programmed similar time date every phone ever picked setting network automatically review mentioned hangup button pressed longer second phone power easy accidentally',
#  'stopped working month use',
#  'placement button particular made confusing elderly father use tried numerous time get phone turn make simple call could get work longer charge come week fortunately cost much waste money',
#  'bought phone simple option year old father like big button charging cradle phone feel cheap afraid break plastic piece pulling cover get battery sim card nstalled different sim card cricket wireless network store could get connected know sure something broken phone incompatibility reviewer saying connected lead think something wrong phone phone going back going try another brand',
#  'giving star know durability everything else perfect say call quality good so speed dial direct dial work great quality phone good docking station issue issue direct charging still rate star everything else perfect',
#  'real nice simple phone grandma',
#  'basic feature necessary senior',
#  'great phone elderly familiar w cell phone number large easier see',
#  'working',
#  'loving',
#  'love simple handset limited number feature find get trouble',
#  'phone difficult unlock unlock phone need press unlock key time first press wake phone second press result message say press unlock key unlock third press unlocks phone easier method unlocking keyboard without disabling lock altogether buying phone someone elderly technology issue may lot difficulty using phone three unlock press done quick enough unlock sequence started unlock key pressed time phone locked instead unlocked difficult explain someone dexterity technology issue never heard phone difficult unlock hard believe easier method unlock phone however called customer support confirmed phone take unlock press unlock phone alternative disable lock feature plus side so key work well require one unlock key so key programmed send text message call another thing note title phone indicates extra today however raised price yesterday saving hate company raise price tell going save paid black friday price lower normal price',
#  'wish ring louder still heard ok hard hearing like everything louder easy work like lot button pushed accidentally might buy friend wondering compatible verizon one problem setting book say go setting tell get setting go left utton key push say phone book keep pushing arrow lead setting unlock phone set ring',
#  'reviewing grandmother bill realized paying month jitterbug phone unlimited talk used minute month text never sent one bought phone add contract line plan month gave work great',
#  'sim card provider would work phone returning phone',
#  'purchased phone parent difficulty small button phone thanks size button display squinting also love key raised menu layout also simple use programmable number make easy call frequently used number ringer volume good would buy',
#  'great phone',
#  'excelente',
#  'phone met expectation dad loved enjoying',
#  'bought elderly grandfather vocal everything get whether like like phone loud simple need glass use able sync',
#  'needed older relative',
#  'gift grandma south america loved thanks',
#  'speaker garbage tell time military time',
#  'bought phone elderly parent put sim card phone jethro worked problem dropped call would receive make phone call phone would hang person line asking refund carrier phone bar phone call took place',
#  'great simple phone getting harder harder find want smartphone need phone elderly family member someone tech savvy great little phone gave four star though carrier recognize signature phone wound buy friendly phone phone work billed system would automatically charge smartphone extra bill since recognize signature giving military reuse',
#  'sim card dose read point selling tablet phone work',
#  'item worth money paid cant find put memory card screen clear blurred item suck',
#  'good phone',
#  'tablet really looking sim card work sd card never read charger cord broke purchase another really upset product really surprise wanted tablet would thing',
#  'charging battery screen wave interference point would use tablet charging returned tablet',
#  'little ok use straighttalk unlimited plan g phone g sim lot chinese apps remove viewing angle screen best however look really sharp straight excellent quality picture video netflix poor camera text network reached friend android kitty kat use google apps voice search excellent decipher worn gravely southern accent every time work well great phone international travel pop european sim extra slot business phablet better camera would steal battery last day used phone surf use wi fi continuously need recharge often going kept used',
#  'tablet worked month giving trouble connect wifi play store access suck',
#  'really nice daughter us everyday almost year still going strong love',
#  'good',
#  'thank best supply',
#  'google play even though picture description say contacted e passion worse useless kept telling stupid stuff like install google play non existent app market obvious understand much english',
#  'upset tablet work sending back replacing',
#  'excellent',
#  'great phablet general us',
#  'liked language mandarin hk also downland apps android store',
#  'friend brought work ordered amazon work together overseas live johannesburg got home tested phone microphone doesnt work hear one hear im stuck would get ut back texas unhappy product',
#  'friend brought work ordered amazon work together overseas live johannesburg got home tested phone microphone doesnt work hear one hear im stuck would get ut back texas unhappy product',
#  'arrived broken forgot send back',
#  'phone worth money plastic flimsy phone hardly work trying return mine waste money',
#  'second sim card use activated phone contacted company still response currently research matter early rate cause phone two week',
#  'little phone great compact easy use love michelleheraud',
#  'little phone great compact easy use love michelleheraud',
#  'little phone great compact easy use love michelleheraud',
#  'hate sending back keep blinking want refund back',
#  'buy work good price would extremely durable average person hvac break lot holster fault',
#  'wonderful got son tends break extra without going hassle ordering thanks rate star',
#  'lasting longer oem',
#  'crear product fast arrived',
#  'work great',
#  'look like original believe original whole lot cheaper',
#  'work nice price bought many',
#  'bought father little month ago able give today put phone holster phone held securely still original otterbox holster compared phone fit snugly holster basically otterbox piece hold phone place replacement holster allows phone slip barely bumped would loved return window passed',
#  'great',
#  'great value one us otterbox defender',
#  'great buy service',
#  'work great',
#  'bought pack still first one seems working well broke hold phone without bulk leather flip case',
#  'thick old one',
#  'purchased pack week back broke third one today brittle slightly smaller need fit defender case last otterbox clip lasted year finally broke would recommend item',
#  'clip break easily ok price',
#  'fit advertised',
#  'like number reviewer break holster every month otterbox good warranty honestly pain get lot knock offs main competitor even worse name mentioned like otterbox used three phone issue holster breakage decided give generic holster try one month using two back ups far issue appear look work well otterbox brand fraction cost break three buy three easier faster get replacement otterbox even mention competitor willing take chance go generic good choice july month later still using first one look like new work perfectly treat gently really happy thus far',
#  'order every month husband phone brake clip thesis good price three help keep ordering every month fit case well clip belt without problem',
#  '',
#  'good product described',
#  'seem original much lower price',
#  'husband break otter box belt clip every month great get pack fit perfect otter box',
#  'seems work fine',
#  'look feel fit like original pressed china instead mexico complaint',
#  'clearly knock first one snapped week couple buck unexpected',
#  'anybody otterbox know belt clip break frequently clip last long brand name much better price fast shipment',
#  'got two belt clip one functioner properly',
#  'download music application come unlocked accessory well good price amazin seller',
#  'hey phone charge insulating film torn idk use understand',
#  'phone powering sent jamaica wi return receive back',
#  'good',
#  'phone alright though come sd card need going install apps',
#  'good price',
#  'sim card slide way slot open phone retrieve chip',
#  'phone memory small work erratically working anymore recommend buy phone',
#  'bought son got connection thru consumer cellular add line work fine included function given problem yet year far buy',
#  'good',
#  'liked design cost worth bought family member far complaint',
#  'work network',
#  'ok phone buy someone',
#  'work short battery life',
#  'good tank',
#  'nice phone buy used traveled outside u loved good smartphone price',
#  'read review fact going say fake five star review bought phone phone absolutely terrible security sticker broken got product contacted seller said okay long phone worked still able use data phone use call text also afraid phone ear burned really hot radiated heat cheaply made touch screen fickle unresponsive zero phone storage apps bottom line wished would spent little money bought different phone',
#  'first thought charging small plastic strip battery needed remove removed phone worked great',
#  'phone horrible speaker work right app never buy phone never recommend anyone thing nice cheap could give phone star would',
#  'got could test android app worked well issue software hardware limited memory forced buy sd card really use still worth price paid',
#  'wife love work great easy use',
#  'phone worked well phone call small internal memory could one app downloaded could send recieve mm battery portal broke owning momths also reset often wifi slow going sea need make call good phone everyday use',
#  'excellent phono low cost',
#  'received phone time packaged well came charger headphone plus however rating three phone feel like toy phone light weight almost feel like break inch drop literally also display hard read bought oldest two child verizon pre paid phone amazon october yes awesome phone going however due quality im going give youngest child looking small cheap phone work though think phone overpriced even',
#  'excelent',
#  'great expected',
#  'love much',
#  'muy bueno',
#  'mom loved screen cracked month later laying purse',
#  'got took forever turn megabyte internal storage even gig sd card quality extremely terrible buy unless want waste money junk',
#  'horrible horrible phone reception keep downloading program buy',
#  'good',
#  'didnt new phone',
#  'small phone compatible u service nice color amazing storage',
#  'work nevera bad',
#  'slow slow slow home network nokia already loaded weather channel local forecast phone still loading restate review terrible viewing angle despite adjustment sensitivity screen finally th tap screen responded request seems hit miss phone usa phone standard probably returning altho great looking phone making receiving call would pretty much paper weight wonder star review sound mysteriously similar language style choice word phrase make wonder fact valid perfect example get pay much update august impressed customer service company received nicest e mail regarding comment asking anything could make purchase right company actually personnel customer service read review purchaser apparently e mailed back forth turn newer model probably mind smart phone going buy also suggested update product information product woefully lacking tech information told process happening also updating review star fabulous responsive customer service company fact phone may right someone exact requirement phone give benefit doubt based review absolutely assured valid honest review purchaser kudos shawyn company',
#  'could gave star would awful phone never seller phone usa standard maybe good across sea use',
#  'really bad literally memory page put stuff would recommend unless wan na call take good pic',
#  'disappointed screen love purple flower see want return back phone feel like using color either n also hard time opening insert sim',
#  'phone work fine would liked extensive instruction far find protective cover',
#  'gave phone birthday gift friend seems happy far',
#  'fan touchscreen phone trusted nokia e gave ghost make transition phone meet need nothing fancy nice size fit perfectly palm finally download whatsapp sibling friend teased end smartphone download app really spec husband techy took look description confirmed would perfect need day far good update review anything change love purple color',
#  'phone seven day impressed setup simple screen quality great processor fast',
#  'extremely fast good looking phone excellent storage option great screen clarity',
#  'recommended charge week use',
#  'phone meet minimum standard network good receive g phone satisfy desire purchase',
#  'never got thing turn would take charge low expectation considering price wanted use back running credit card using square going work returning',
#  'bought phone gift recieved phone work pay return cellphone venezuela usa',
#  'work',
#  'simple enough plenty function',
#  'excelent',
#  'product expensive quality might worth maybe better adding little extra getting used second third generation galaxy iphone definitely last longer regret purchase screen went south week use also screen quality ideal',
#  'better expected',
#  'say mobile compatible however sim card inserted connect would say sim connecting network great price nothing use phone wi fi avail calling service away home phone cute needed apps home',
#  'excellent',
#  'bad',
#  'cheap phone thought gave try guess wanted good low internal memory lot ad thrown also freeze quite bit guess good want use talk travel dual sim card slot',
#  'like phone horrible phone',
#  'slow regret buying suggest different phone',
#  'excellent',
#  'hate phone week later buy another one slow storage poor waste money never',
#  'bad',
#  'good getting heat talk five minute',
#  'piece crap',
#  'took phone mexico surfed web made call voip regular phone heroic camera bad either',
#  'bueno',
# ...
#  'ok best cell phone work ok venezuelan digitel movistar movilnet',
#  'smartphone excellent dig little setting change language english spanish quick long life battery recommend google play le man',
#  'great phone price large screen browse web easy use speed ok wifi g situation drawback battery life last hour may need extra batter mobile battery better check seller make sure phone rooted carrier neutral got phone pre installed china unicom take time uninstall carrier software',
#  'good phone seller say come googleplay q lie brings application chinese',
#  'bought phone work great scary thing speaks everything chinese speak english yikes husband took phone phone dealer change language setting buy phone see speaks another language simply take phone dealer top line phone fraction price',
#  'little visibility light environment like outside shadow battery life could better big screen good reading text',
#  'great phone',
#  'exelente',
#  'good evening writing notify product already reached hand good condition present several problem one one box phone come without security seal without adhesive inner side compared phone brings brings two one iridescent one bar code problem presented greatest one phone adhesive problem getting charger connect original lenovo charger brought package minute maximum accepts register charge light turn stop charging battery wonder procedure case necessary forwarding phone direction thanking prompt response problem present say goodbye gaudy fermin',
#  'excellent',
#  'ring good',
#  'excelent',
#  'awful definetely',
#  'fine',
#  'muy bueno',
#  'excelente',
#  'cell phone arrived several day expected mobil work excellent fast big screen look good problem camera night good price think good mobil',
#  'cel many flaw remains stuck restarts falla hedge son came many esta tel bad computer operating',
#  'reached tlf',
#  'yes item selected',
#  'love good product best service',
#  'excelent',
#  'work excellent argentina good quality',
#  'phone g even add say g internet run super slow second sim card work properly shame cause nice phone detail using call text wifi ok',
#  'excelente muy bueno',
#  'excelente muy bueno',
#  'date phone android flaw buck unbeatable quality beautiful design easily pas phone cost lenovo recognizable brand trust durable name cheap phone',
#  'excelente',
#  'excellent',
#  'mobile good small detail make uncomfortable using button activate screen awkward position otherwise sastifecho',
#  'okay',
#  'feature amazing clean neat',
#  'great phone easy access application work perfectly venezuela recommend',
#  'congratulection ok',
#  'uff love smartphone really work venezuelan service',
#  'liked later gave friend plan buy another one return home usa',
#  'nice phone game worked well straight talk',
#  'excellent product came good stuff pen drive case screen protector',
#  'five star excellent',
#  'left side screen vertical area inch touch response way chinese software retarded hard correct remove despite rooted superuser app preinstalled using multiple apps performance really start struggle support otg youtube app become glitchy unknown reason pro large screen decent resolution large battery fm radio nice back temp phone looking flash rom custom install future update completed',
#  'like phone nice camera',
#  'odlican telefon usluga',
#  'phone good phone yeah right g slow without using wifi',
#  'good',
#  'great thanks number responsibility came good',
#  'excelente',
#  'asked people question amazon whether would work digi mobil movistar everyone said would required sim adapter review anyone give phone star never owned premium smartphone review comparing samsung galaxy touchscreen factory provided screen protector sometimes unresponsive sometimes freeze hold touch screen button time phone realize touched le half time button respond take screen protector work marvelously risk damaging screen network movistar digimobil pay go plan got sim bought samsung galaxy young use major issue aside phone size young whatsapp worked fine could send text make phone call whatsapp mobile network wifi sim lenovo allow transmit whatsapp unless connected wifi addition internet google play access without wifi phone returned',
#  'useless chinese',
#  'good phone price',
#  'excellent',
#  'lenovo pone pone kid toy plea remove market thank rate',
#  'chinese menu hard operate',
#  'disappointed waste money much hassle return',
#  'excellent fash',
#  'excelent',
#  'good buena',
#  'excelente producto',
#  'excelent',
#  'awesome bought one husband one',
#  'phone quite big perfect dad mostly use phone play candy crush send text totally love fast perfect deal price',
#  'excellent',
#  'buen celular',
#  'good phone sent defective sound call used headphone ideal take repair',
#  'phone working',
#  'excelente',
#  'good mobile',
#  'nice product reasonable shipping speed language setting somewhat challenge initial language greek help google translator changed english eventually',
#  'amazing phone cable case included also screen pritectors amazing phone',
#  'excelent',
#  'excellent meet requirement requested',
#  'good',
#  'good basically chinese phone google play returned product within hour since go delivered would suggest buy phone',
#  'total disappointment team come chinese english described spanish worst longer android google installed play apk download permitted run app google inc una total decepci n el equipo viene solo en chino e ingles en espa ol como describe lo peor e que tiene android ya que tiene instalado google play al bajarlo como apk permite ejecutar la app ni ninguna otra de google inc',
#  'found feature worked properly without glitch mine came google play included worked fine operating system proper english found calendar application chinese character use application disabled usual android phone came many application uninstalled disabled use disappear icon screen big nice phone still fit shirt pocket even case also bought amazon used sim miami another one costa rica travel frequently worked fine first time phone came without setup manual newbie may download one internet',
#  'everything work like described satisfied product far surprisely problem would recommend anyone',
#  'product represents everything brand suggests good quality product well packaged accessory part good overall condition new mind appears image company grateful recommend product',
#  'good performance touchscreen display okgoogle play store apps working without problem make sure operator support g phone',
#  'good smartphone prize cpu really fast big screen let enjoy apps great size',
#  'tried several phone year including two nexus galaxy note none approach one fluid easy use everything work described screen seems large paper guarantee feel start using received phone time seller great job playstore preinstalled taking much time come downloaded neflix internet directly install playstore started work even without playstore preinstalled still install apps playstore webpage restriction',
#  'excellent price quality ratio although operating system modified version lenovo hope soon available version cosinadas versatility',
#  'first android phone iphones till starting show age instead spending well iphone c decided try android nexus like lenovo spec looking feedback convinced try especially since cost little amazon including shipping yeah wait delivered china take long caveat like gb memory storage microsd card swapping gb card flashing cleaner version lenovo iteration android really enjoying power responsiveness mediatek processor gb ram seems ample general use watched video decent gameing handled well also like battery life stop buying extra battery battery charger since swap battery making never really needing sit charge unless want bottom line know way around android even novice like gon na really like phone keep expectation equal price paying',
#  'ordered friday lightinthebox home store delivered dhl next tuesday impressive good mobile bright display single con contained china english softwear version needed upgraded even chose english version sometimes see chinese letter softwear changing process took approximately minute good mobile price le',
#  'thank gift sent package screen protectorgood performance touchscreen display okgoogle play store apps working without problem perfect usable smartphone tablet combination device',
#  'good performance touchscreen display ok quite big good seniorsgoogle play store apps working without problem thing worry chinese language boot menu chinese message menu entry show seldom deeper setting using germany local language setting gui work fine declared root pseudo seriously rootable son got minute web search perfect usable smartphone tablet combination device bought lightonlines',
#  'lenovo chinese phone android operating system phone chinese cant install google play get around root phone install custom rom english hence bought phone rooted google play case phone programed chinese everything written chinese character google play function standard operating system phone seller used false advertising product description bad man make cry phone google play pre installed flash root phone install',
#  'good smart phone first device fast lagging software nice battery life accepted daily use feel good hand camera really expected cost great deal quad core gb ram big screen bad camera nice finishing style',
#  'thank gift sent package screen protector case nice thank',
#  'nice product price',
#  'happy fulfilled expectation love phone phone good price recommend',
#  'excelent',
#  'good phone excellent hardware good performance high compatibility international operator venezuela',
#  'bought brother loved screen size resolution great',
#  'since received phone turn work bad phone',
#  'phone fantastic better thought bad thing chinese venezuela change language spanish',
#  'nice cell need quality control recognize sim card port think last time buy amazon cell fork success',
#  'excelente',
#  'excelent',
#  'good cellphone',
#  'would stay return',
#  'excelent choice cellphone',
#  'phone bag open box ok',
#  'excellent',
#  'super fast shipping love seller happy smartphone thank',
#  'received phone yesterday rooted root phone nice fast far keep guy posted anything new',
#  'work well great value',
#  'fine',
#  'good',
#  'lo vendi',
#  'phone made china plan use phone outside china buy phone configured work china even time clock phone set china time zone change phone accept change install new apps make change pre installed apps number chinese junk apps pre installed phone often give message chinese language also crash frequently get several error message need rebooted frequently change made get lost time reboots text message contact even disappear randomly battery drain quickly stay away piece junk living china',
#  'love unfortunate accompanied english manual guide',
#  'hurt week later provide defective good',
#  'like good seller nice cellphone useful phone use philippine nothing problem',
#  'todo perfecto',
#  'excelente',
#  'think repair phone give phone work anything turn hate worst phone ever buy plastic aluminium stole',
#  'phone lighting fast however allows change language setting english chinese routed goole play store lenovo store chinese buy amazon try help help',
#  'one bought dealextreme working really well many drop remember main reason buying since quite clumsy holding cell secondly think cel quite fast price even though picture quality great pair high def camera point click ok hope would come memory could complain since price seems right',
#  'excelente',
#  'returned broken screen',
#  'exelent',
#  'excelente',
#  'good phone acording cost',
#  'ok',
#  'best price value benefit deal chinese lenovo built apps english lenovo great brand',
#  'excelente',
#  'excellent product arrived good condition good quality',
#  'item returned',
#  'ver good',
#  'excellent product',
#  'excelente',
#  'time excellent',
#  'good excellent equip',
#  'excellent',
#  'look great instruction chinese speak english difficult learning new tapping technique light tap several time work screen went black week requested return slip day three still waiting',
#  'excellent',
#  'decent phone price really complain serf purpose',
#  'good thanks',
#  '',
#  'know good phone month yet know good bad survise',
#  'use phone six month charging point stop working language chinese waste money time',
#  'nice item',
#  'well cellphone excellent fast problem lenguage mixed example spanish apps lenguage appear un chinese unique one problem happy',
#  'love',
#  'excelent',
#  'excelent',
#  'latest review gone live amazon million shopper amazon appreciate time took write experience item reviewing statsno profile image review written reviewer rank would like add review always edit product imagerca unlocked dual sim star star five star april deivis rosstaverified purchase review rca unlocked dual sim mp camera android ghz white wireless phone accessory satisfied purchase expected thank much recommendsee review sitereview purchase',
#  'scam becareful',
#  'excelent price',
#  'absolutely recommended product exlusively asian market lenovo provide technical service worldwide smartphones interface pc chinese language recomended consumer advanced knowledge programming chinese course p item technical issue charger slot knowing deal customer actually prefer even write never',
#  'excellent',
#  'love',
#  'great phone price',
#  ...]

# %%
#Cleaning BagOfWords
from sklearn.feature_extraction.text import CountVectorizer

max_f=1000
CntVec = CountVectorizer(max_features = max_f)
sparse_mat = CntVec.fit_transform(texts).toarray()
words = CntVec.get_feature_names()
words
# Out:
# ['ability',
#  'able',
#  'absolutely',
#  'access',
#  'accessory',
#  'acer',
#  'across',
#  'activate',
#  'activated',
#  'actual',
#  'actually',
#  'add',
#  'added',
#  'additional',
#  'advertised',
#  'affect',
#  'affordable',
#  'afraid',
#  'ago',
#  'alarm',
#  'alcatel',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amazing',
#  'amazon',
#  'amount',
#  'android',
#  'angle',
#  'another',
#  'answer',
#  'anymore',
#  'anyone',
#  'anything',
#  'anyway',
#  'apn',
#  'app',
#  'apple',
#  'application',
#  'apps',
#  'area',
#  'around',
#  'arrived',
#  'asha',
#  'ask',
#  'asked',
#  'att',
#  'audio',
#  'automatically',
#  'available',
#  'average',
#  'away',
#  'awesome',
#  'awful',
#  'back',
#  'bad',
#  'band',
#  'bar',
#  'barely',
#  'based',
#  'basic',
#  'basically',
#  'battery',
#  'beat',
#  'beautiful',
#  'beep',
#  'began',
#  'believe',
#  'benefit',
#  'best',
#  'better',
#  'big',
#  'bigger',
#  'bill',
#  'bit',
#  'black',
#  'blue',
#  'bluetooth',
#  'bother',
#  'bottom',
#  'bought',
#  'box',
#  'brand',
#  'break',
#  'bright',
#  'bring',
#  'broke',
#  'broken',
#  'brother',
#  'browse',
#  'browser',
#  'browsing',
#  'buck',
#  'budget',
#  'bueno',
#  'build',
#  'built',
#  'button',
#  'buy',
#  'buying',
#  'cable',
#  'calendar',
#  'call',
#  'called',
#  'calling',
#  'came',
#  'camera',
#  'cant',
#  'capability',
#  'capable',
#  'car',
#  'card',
#  'care',
#  'careful',
#  'carrier',
#  'carry',
#  'case',
#  'cell',
#  'cellphone',
#  'cellular',
#  'certain',
#  'change',
#  'charge',
#  'charged',
#  'charger',
#  'charging',
#  'cheap',
#  'check',
#  'checked',
#  'china',
#  'chinese',
#  'chip',
#  'choice',
#  'choose',
#  'chrome',
#  'clarity',
#  'clean',
#  'clear',
#  'clearly',
#  'click',
#  'clip',
#  'clock',
#  'close',
#  'color',
#  'come',
#  'comfortable',
#  'coming',
#  'compact',
#  'company',
#  'comparable',
#  'compare',
#  'compared',
#  'comparison',
#  'compatible',
#  'complain',
#  'complaint',
#  'complete',
#  'completely',
#  'computer',
#  'con',
#  'condition',
#  'connect',
#  'connected',
#  'connecting',
#  'connection',
#  'constantly',
#  'contact',
#  'contract',
#  'convenient',
#  'cool',
#  'core',
#  'cost',
#  'could',
#  'country',
#  'couple',
#  'course',
#  'cover',
#  'coverage',
#  'cpu',
#  'crack',
#  'cracked',
#  'crash',
#  'cricket',
#  'crisp',
#  'currently',
#  'customer',
#  'dad',
#  'daily',
#  'data',
#  'date',
#  'daughter',
#  'day',
#  'dead',
#  'deal',
#  'decent',
#  'default',
#  'defective',
#  'definitely',
#  'delivered',
#  'delivery',
#  'described',
#  'description',
#  'design',
#  'despite',
#  'detail',
#  'device',
#  'dialing',
#  'didnt',
#  'died',
#  'difference',
#  'different',
#  'difficult',
#  'direction',
#  'directly',
#  'disappointed',
#  'discount',
#  'discounted',
#  'display',
#  'doesnt',
#  'dollar',
#  'done',
#  'dont',
#  'download',
#  'downloaded',
#  'downloading',
#  'downloads',
#  'downside',
#  'drain',
#  'drop',
#  'dropped',
#  'dual',
#  'due',
#  'durability',
#  'durable',
#  'ear',
#  'earbuds',
#  'earlier',
#  'earphone',
#  'easier',
#  'easily',
#  'easy',
#  'either',
#  'elderly',
#  'else',
#  'email',
#  'end',
#  'ended',
#  'english',
#  'enjoy',
#  'enough',
#  'error',
#  'especially',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everyday',
#  'everyone',
#  'everything',
#  'example',
#  'excelent',
#  'excelente',
#  'excellent',
#  'except',
#  'exchange',
#  'excited',
#  'exelente',
#  'expect',
#  'expectation',
#  'expected',
#  'expecting',
#  'expensive',
#  'experience',
#  'experienced',
#  'extra',
#  'extremely',
#  'eye',
#  'facebook',
#  'facing',
#  'fact',
#  'factor',
#  'factory',
#  'fair',
#  'family',
#  'fantastic',
#  'far',
#  'fast',
#  'faster',
#  'father',
#  'fault',
#  'favorite',
#  'feature',
#  'feedback',
#  'feel',
#  'fi',
#  'figure',
#  'figured',
#  'file',
#  'film',
#  'finally',
#  'find',
#  'finding',
#  'fine',
#  'fingerprint',
#  'first',
#  'fit',
#  'five',
#  'fix',
#  'flagship',
#  'flash',
#  'flashlight',
#  'flip',
#  'fm',
#  'foreign',
#  'forever',
#  'form',
#  'found',
#  'four',
#  'free',
#  'freeze',
#  'friend',
#  'friendly',
#  'front',
#  'frustrating',
#  'full',
#  'fully',
#  'function',
#  'functionality',
#  'galaxy',
#  'game',
#  'garbage',
#  'gave',
#  'gb',
#  'general',
#  'generation',
#  'get',
#  'getting',
#  'gift',
#  'gig',
#  'give',
#  'given',
#  'glad',
#  'glass',
#  'go',
#  'going',
#  'gold',
#  'good',
#  'google',
#  'got',
#  'gps',
#  'great',
#  'gsm',
#  'guess',
#  'guy',
#  'half',
#  'hand',
#  'handle',
#  'hang',
#  'happened',
#  'happy',
#  'hard',
#  'harder',
#  'hardware',
#  'hate',
#  'hd',
#  'headphone',
#  'headset',
#  'hear',
#  'heard',
#  'hearing',
#  'heavy',
#  'help',
#  'high',
#  'higher',
#  'highly',
#  'hit',
#  'hold',
#  'holding',
#  'holster',
#  'home',
#  'honest',
#  'honestly',
#  'hope',
#  'hoping',
#  'horrible',
#  'hot',
#  'hour',
#  'house',
#  'however',
#  'htc',
#  'huge',
#  'hundred',
#  'husband',
#  'icon',
#  'idol',
#  'im',
#  'image',
#  'immediately',
#  'important',
#  'impressed',
#  'impressive',
#  'inch',
#  'included',
#  'includes',
#  'including',
#  'incredible',
#  'inexpensive',
#  'information',
#  'insert',
#  'inside',
#  'install',
#  'installed',
#  'instead',
#  'instruction',
#  'interface',
#  'internal',
#  'international',
#  'internet',
#  'intuitive',
#  'iphone',
#  'issue',
#  'item',
#  'jbl',
#  'jethro',
#  'job',
#  'juning',
#  'junk',
#  'keep',
#  'kept',
#  'key',
#  'keyboard',
#  'kind',
#  'know',
#  'lack',
#  'lag',
#  'language',
#  'laptop',
#  'large',
#  'larger',
#  'last',
#  'lasted',
#  'late',
#  'later',
#  'latest',
#  'law',
#  'le',
#  'learn',
#  'least',
#  'leave',
#  'led',
#  'left',
#  'lenovo',
#  'let',
#  'lg',
#  'life',
#  'light',
#  'lighting',
#  'like',
#  'liked',
#  'limited',
#  'line',
#  'listen',
#  'listening',
#  'literally',
#  'little',
#  'live',
#  'load',
#  'location',
#  'lock',
#  'locked',
#  'lollipop',
#  'long',
#  'longer',
#  'look',
#  'looked',
#  'looking',
#  'lost',
#  'lot',
#  'loud',
#  'louder',
#  'love',
#  'loved',
#  'loving',
#  'low',
#  'lower',
#  'lte',
#  'made',
#  'mail',
#  'main',
#  'make',
#  'making',
#  'manual',
#  'many',
#  'market',
#  'marshmallow',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'medium',
#  'megapixel',
#  'memory',
#  'mention',
#  'mentioned',
#  'menu',
#  'message',
#  'messaging',
#  'messenger',
#  'metro',
#  'micro',
#  'microphone',
#  'mid',
#  'might',
#  'mind',
#  'mine',
#  'mini',
#  'minute',
#  'missing',
#  'mm',
#  'mobil',
#  'mobile',
#  'mode',
#  'model',
#  'mom',
#  'moment',
#  'money',
#  'month',
#  'mother',
#  'moto',
#  'move',
#  'movie',
#  'mp',
#  'much',
#  'music',
#  'must',
#  'muy',
#  'na',
#  'name',
#  'necessary',
#  'need',
#  'needed',
#  'negative',
#  'network',
#  'never',
#  'new',
#  'next',
#  'nexus',
#  'nice',
#  'niece',
#  'night',
#  'nokia',
#  'non',
#  'none',
#  'normal',
#  'note',
#  'nothing',
#  'notice',
#  'noticed',
#  'notification',
#  'number',
#  'obvious',
#  'october',
#  'offer',
#  'often',
#  'ok',
#  'okay',
#  'old',
#  'one',
#  'onetouch',
#  'online',
#  'open',
#  'opened',
#  'opening',
#  'operate',
#  'operating',
#  'operation',
#  'opinion',
#  'option',
#  'order',
#  'ordered',
#  'ordering',
#  'original',
#  'otherwise',
#  'otterbox',
#  'outside',
#  'overall',
#  'owned',
#  'pack',
#  'package',
#  'packaging',
#  'page',
#  'paid',
#  'pandora',
#  'paper',
#  'part',
#  'pay',
#  'paying',
#  'pc',
#  'people',
#  'perfect',
#  'perfectly',
#  'performance',
#  'person',
#  'personal',
#  'personally',
#  'phablets',
#  'phone',
#  'photo',
#  'pic',
#  'pick',
#  'picture',
#  'piece',
#  'pink',
#  'pixel',
#  'place',
#  'placed',
#  'plan',
#  'plastic',
#  'play',
#  'player',
#  'playing',
#  'please',
#  'pleased',
#  'plenty',
#  'plug',
#  'plus',
#  'pocket',
#  'point',
#  'poor',
#  'pop',
#  'port',
#  'positive',
#  'power',
#  'powerful',
#  'pre',
#  'prepaid',
#  'press',
#  'pretty',
#  'previous',
#  'price',
#  'priced',
#  'pro',
#  'probably',
#  'problem',
#  'process',
#  'processor',
#  'produce',
#  'product',
#  'properly',
#  'protection',
#  'protector',
#  'provide',
#  'provider',
#  'purchase',
#  'purchased',
#  'purchasing',
#  'put',
#  'quad',
#  'quality',
#  'quick',
#  'quickly',
#  'quite',
#  'radio',
#  'ram',
#  'random',
#  'randomly',
#  'range',
#  'rate',
#  'rather',
#  'rating',
#  'read',
#  'reading',
#  'ready',
#  'real',
#  'realize',
#  'really',
#  'rear',
#  'reason',
#  'reasonable',
#  'receive',
#  'received',
#  'receiving',
#  'reception',
#  'recognize',
#  'recomend',
#  'recommend',
#  'recommended',
#  'record',
#  'reduced',
#  'refund',
#  'regret',
#  'regular',
#  'relative',
#  'reliable',
#  'remember',
#  'remove',
#  'removed',
#  'repair',
#  'repaired',
#  'replace',
#  'replaced',
#  'replacement',
#  'replacing',
#  'research',
#  'reset',
#  'resolution',
#  'response',
#  'responsive',
#  'result',
#  'return',
#  'returned',
#  'returning',
#  'reversible',
#  'review',
#  'right',
#  'ring',
#  'rom',
#  'root',
#  'rooted',
#  'rooting',
#  'run',
#  'running',
#  'said',
#  'samsung',
#  'satisfied',
#  'save',
#  'saw',
#  'say',
#  'saying',
#  'scratch',
#  'screen',
#  'sd',
#  'search',
#  'second',
#  'security',
#  'see',
#  'seem',
#  'seemed',
#  'seems',
#  'seen',
#  'selfie',
#  'selfies',
#  'sell',
#  'seller',
#  'send',
#  'sending',
#  'senior',
#  'sensor',
#  'sent',
#  'service',
#  'set',
#  'setting',
#  'setup',
#  'several',
#  'sharp',
#  'shipped',
#  'shipping',
#  'shopping',
#  'short',
#  'shot',
#  'show',
#  'showing',
#  'side',
#  'signal',
#  'sim',
#  'simcard',
#  'similar',
#  'simple',
#  'simply',
#  'sims',
#  'since',
#  'single',
#  'situation',
#  'size',
#  'sleek',
#  'slight',
#  'slightly',
#  'slim',
#  'slot',
#  'slow',
#  'slower',
#  'small',
#  'smaller',
#  'smart',
#  'smartphone',
#  'smartphones',
#  'smooth',
#  'smoothly',
#  'snapchat',
#  'snappy',
#  'so',
#  'social',
#  'software',
#  'sold',
#  'solid',
#  'someone',
#  'something',
#  'sometimes',
#  'son',
#  'song',
#  'soon',
#  'sound',
#  'space',
#  'spanish',
#  'speak',
#  'speaker',
#  'spec',
#  'special',
#  'speed',
#  'spend',
#  'spent',
#  'spot',
#  'sprint',
#  'standard',
#  'standby',
#  'star',
#  'start',
#  'started',
#  'stay',
#  'stereo',
#  'still',
#  'stock',
#  'stop',
#  'stopped',
#  'storage',
#  'store',
#  'straight',
#  'strong',
#  'stuck',
#  'stuff',
#  'style',
#  'suck',
#  'super',
#  'support',
#  'supported',
#  'supposed',
#  'sure',
#  'surfing',
#  'surprised',
#  'surprisingly',
#  'swap',
#  'switch',
#  'system',
#  'tab',
#  'tablet',
#  'tag',
#  'take',
#  'taken',
#  'taking',
#  'talk',
#  'tap',
#  'task',
#  'team',
#  'tech',
#  'technology',
#  'tell',
#  'term',
#  'terrible',
#  'test',
#  'tested',
#  'tethering',
#  'text',
#  'texting',
#  'th',
#  'thank',
#  'thanks',
#  'thin',
#  'thing',
#  'think',
#  'though',
#  'thought',
#  'three',
#  'throw',
#  'time',
#  'tmobile',
#  'today',
#  'told',
#  'ton',
#  'took',
#  'top',
#  'total',
#  'totally',
#  'touch',
#  'touchscreen',
#  'tracfone',
#  'transfer',
#  'travel',
#  'traveling',
#  'tried',
#  'trouble',
#  'true',
#  'trust',
#  'try',
#  'trying',
#  'turn',
#  'turned',
#  'turning',
#  'twice',
#  'two',
#  'type',
#  'typing',
#  'unable',
#  'unbiased',
#  'understand',
#  'uninstall',
#  'unit',
#  'unless',
#  'unlike',
#  'unlock',
#  'unlocked',
#  'update',
#  'updated',
#  'upgrade',
#  'upgraded',
#  'ur',
#  'us',
#  'usa',
#  'usage',
#  'usb',
#  'use',
#  'used',
#  'useful',
#  'useless',
#  'user',
#  'using',
#  'usually',
#  'value',
#  'vendor',
#  'venezuela',
#  'verizon',
#  'version',
#  'video',
#  'viewing',
#  'virus',
#  'voice',
#  'volume',
#  'vr',
#  'wait',
#  'wake',
#  'wallpaper',
#  'want',
#  'wanted',
#  'wanting',
#  'warranty',
#  'waste',
#  'watch',
#  'watching',
#  'water',
#  'way',
#  'wcdma',
#  'web',
#  'week',
#  'weight',
#  'well',
#  'went',
#  'whatever',
#  'whatsapp',
#  'white',
#  'whole',
#  'wi',
#  'wide',
#  'wife',
#  'wifi',
#  'willing',
#  'window',
#  'wireless',
#  'wish',
#  'within',
#  'without',
#  'wonder',
#  'wonderful',
#  'wont',
#  'word',
#  'work',
#  'worked',
#  'working',
#  'world',
#  'worried',
#  'worry',
#  'worse',
#  'worst',
#  'worth',
#  'would',
#  'wow',
#  'write',
#  'writing',
#  'wrong',
#  'wrote',
#  'year',
#  'yes',
#  'yet',
#  'youtube',
#  'zero']

# %%
#creating the feature matrix and target vector
X =sparse_mat
y = df.iloc[:,1].values

# %%
#splitting the training and testing data
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, accuracy_score
classifier = MultinomialNB()
classifier.fit(xtrain, ytrain)

y_pred = classifier.predict(xtest)
print("Accuracy_score: ", accuracy_score(ytest,y_pred))
# Out:
# Accuracy_score:  0.7162162162162162

# %%
#fitting data and predicting using RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=30)
model.fit(xtrain,ytrain)

y_pred = model.predict(xtest)

from sklearn.metrics import accuracy_score
print("Accuracy_score: ", accuracy_score(ytest,y_pred))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(ytest, y_pred)
print(cm)
# Out:
# Accuracy_score:  0.7486486486486487
# [[ 66   2   1  18]
#  [ 14  12   2   5]
#  [  7   3  21  20]
#  [ 10   0  11 178]]

# %%
#for better accuracy trying LogisyicRegression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(xtrain,ytrain)

y_pred_lr = lr.predict(xtest)
print("Accuracy_score: ",accuracy_score(ytest,y_pred_lr))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy_score:  0.7764833378488215

# %%
#Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(xtrain, ytrain)

y_pred1 = classifier.predict(xtest)
print("Accuracy_score: ",accuracy_score(ytest,y_pred1))
# Out:
# Accuracy_score:  0.7946356001083718

# %%
#Fitting DTC o the training set
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 1)
classifier.fit(xtrain, ytrain)

y_pred2 = classifier.predict(xtest)
print("Accuracy_score: ",accuracy_score(ytest,y_pred2))
# Out:
# Accuracy_score:  0.6864864864864865
